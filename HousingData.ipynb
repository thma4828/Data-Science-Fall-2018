# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data', header=None, sep='\s+')
df.columns = ['CRIME', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RMS', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
df.head()
# Out:
#      CRIME    ZN  INDUS  CHAS    NOX    RMS   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
sns.set(style='whitegrid', context='notebook')
cols = ['LSTAT', 'INDUS', 'NOX', 'RMS', 'MEDV']
sns.pairplot(df[cols], size=2.5)

# %%
df.head(3)
# Out:
#      CRIME    ZN  INDUS  CHAS    NOX    RMS   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
X_test, y_test = df.iloc[0:250, 5].values, df.iloc[0:250, 13].values

# %%
X_train, y_train = df.iloc[250:, 5].values, df.iloc[250:, 13].values

# %%
plt.scatter(X_train, y_train)
plt.show()

# %%
lr.fit(X_train.reshape(-1, 1), y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.coef_[0]
# Out:
# 7.34008583612967

# %%
lr.intercept_
# Out:
# -24.995994560580428

# %%
import numpy as np
def f(x):
    return -25.0 + (7.34*x)

xrange = np.arange(0.0, 10.0, 0.1)
yvals = [f(x) for x in xrange]

plt.plot(xrange, yvals, color='green')
plt.scatter(X_train, y_train)

# %%
f(20)
# Out:
# 121.80000000000001
